# %% [markdown]
# # Visualisation of Twitter stats to somewhat determine best time to tweet

# %%
import numpy as np
import pandas as pd
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt

# %% [markdown]
# ### get created csv file

# %%
twitter_stats = pd.read_csv("../twitter-analytics-visualization/tweet_analytics.csv", sep=r'\s*,\s*', header=0, encoding='ascii', engine="python")
twitter_stats
# Out:
#     day  time  impressions  followers
# 0     0    11          214         81
# 1     1    14          397         90
# 2     2     4          610         91
# 3     3     5          453         91
# 4     4     5          423         92
# 5     5     3          920         94
# 6     6     4          456        110
# 7     7     3          136        108
# 8     8     5          469        110
# 9     9     4          232        109
# 10   10     3          446        113
# 11   11    14          209        113
# 12   12     4          377        115
# 13   13     3          177        119
# 14   14     3          210        120
# 15   15     7          179        121
# 16   16     5          257        123
# 17   17     5         1445        130
# 18   18    17          300        133

# %% [markdown]
# # Summary

# %%
twitter_stats.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Linear Graph: Time vs Impressions (Attempt 1)

# %%
# need to learn more on plotting linear graphs it seems :) 
twitter_stats.plot(x='time', y='impressions')
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
#  ## Histogram: Time vs Impressions (Attempt 1)

# %%
# Success! 
plt.bar(twitter_stats["time"], twitter_stats["impressions"] ,align='center') # A bar chart
plt.xlabel('Tweeting Time (hours)')
plt.ylabel('Impressions')

plt.show()

# %% [markdown]
# ### I clearly do not know what I'm trying to do

# %%
pd.crosstab(twitter_stats["time"], twitter_stats["impressions"]).plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
twitter_stats["time"].plot()
# Out:
# <AxesSubplot:>
